# %% [markdown]
# # **EDA, CONFIG & CLEANER WALKTHROUGH**
# ---
# ___

# %% [markdown]
# **CONFIG**

# %%
from pathlib import Path

# %% [markdown]
# Dòng lệnh dùng để nhập (import) class Path từ thư viện pathlib của Python.

# %%
BASE_DIR = Path(__file__).parent.parent
DATA_DIR = BASE_DIR / "data"
RAW_DATA_PATH = DATA_DIR / "raw" / "US_Accidents_March23.csv"

# %% [markdown]
# Đoạn code này dùng để thiết lập hệ thống đường dẫn "động" (dynamic paths) cho dự án.
# Mục đích chính của nó là để code có thể chạy được trên bất kỳ máy tính nào mà không cần phải sửa lại đường dẫn thủ công. Với:
# + <span style="color:#ec9ca4">BASE_DIR</span> <span style="color:#74e5ff">=</span> <span style="color:#fff99e">Path</span><span style="color:yellow">(</span><span style="color:#ec9ca4">___ file ___</span><span style="color:yellow">)</span>.<span style="color:#ec9ca4">parent</span>.<span style="color:#ec9ca4">parent</span>: là thư mục gốc của dự án (US-Accidents-main) sẽ được chuyển sang biến BASE_DIR.
# + <span style="color:#ec9ca4">DATA_DIR</span> <span style="color:#74e5ff">=</span> <span style="color:#ec9ca4">BASE_DIR</span> <span style="color:#74e5ff">/</span> <span style="color:#c2e2a8">"data"</span>: xác định folder chứa dữ liệu. Tạo ra đường dẫn .../US-Accidents-main/data
# + <span style="color:#ec9ca4">RAW_DATA_PATH</span> <span style="color:#74e5ff">=</span> <span style="color:#ec9ca4">DATA_DIR</span> <span style="color:#74e5ff">/</span> <span style="color:#c2e2a8">"raw"</span> <span style="color:#74e5ff">/</span> <span style="color:#c2e2a8">"US_Accidents_March23.csv"</span>: xác định file csv cần đọc với đường dẫn .../US-Accidents-main/data/raw/US_Accidents_March23.csv

# %%
PROCESSED_DIR = DATA_DIR / "processed"
CLEANED_DIR = PROCESSED_DIR / "cleaned"
DIM_DIR = PROCESSED_DIR / "dimensions"
FACT_DIR = PROCESSED_DIR / "fact"
AGG_DIR = PROCESSED_DIR / "aggregates"

# %% [markdown]
# + <span style="color:#ec9ca4">PROCESSED_DIR</span> <span style="color:#74e5ff">=</span> <span style="color:#ec9ca4">DATA_DIR</span> <span style="color:#74e5ff">/</span> <span style="color:#c2e2a8">"processed"</span>: chứa đường dẫn tới .../US-Accidents-main/data/processed
# + <span style="color:#ec9ca4">CLEANED_DIR</span> <span style="color:#74e5ff">=</span> <span style="color:#ec9ca4">PROCESSED_DIR</span> <span style="color:#74e5ff">/</span> <span style="color:#c2e2a8">"cleaned"</span>: chứa đường dẫn tới .../US-Accidents-main/data/processed/cleaned
# + <span style="color:#ec9ca4">DIM_DIR</span> <span style="color:#74e5ff">=</span> <span style="color:#ec9ca4">PROCESSED_DIR</span> <span style="color:#74e5ff">/</span> <span style="color:#c2e2a8">"dimensions"</span>: chứa đường dẫn tới .../US-Accidents-main/data/processed/dimensions
# + <span style="color:#ec9ca4">FACT_DIR</span> <span style="color:#74e5ff">=</span> <span style="color:#ec9ca4">PROCESSED_DIR</span> <span style="color:#74e5ff">/</span> <span style="color:#c2e2a8">"fact"</span>: chứa đường dẫn tới .../US-Accidents-main/data/processed/fact
# + <span style="color:#ec9ca4">AGG_DIR</span> <span style="color:#74e5ff">=</span> <span style="color:#ec9ca4">PROCESSED_DIR</span> <span style="color:#74e5ff">/</span> <span style="color:#c2e2a8">"aggregates"</span>: chứa đường dẫn tới .../US-Accidents-main/data/processed/aggregates

# %%
START_YEAR = 2019
END_YEAR = 2022

# %% [markdown]
# + <span style="color:#ec9ca4">START_YEAR</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">2019</span>
# + <span style="color:#ec9ca4">END_YEAR</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">2022</span>
#
# Mục đích: lấy dữ liệu từ năm 2019 đến 2022

# %%
TEMP_MIN = -20
TEMP_MAX = 120
VISIBILITY_MAX = 10
DURATION_MAX_HOURS = 24
PRECIPITATION_MAX = 5

# %% [markdown]
#     Gán:
# + <span style="color:#ec9ca4">TEMP_MIN</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">-20</span>
# + <span style="color:#ec9ca4">TEMP_MAX</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">120</span>
# + <span style="color:#ec9ca4">VISIBILITY_MAX</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">10</span>
# + <span style="color:#ec9ca4">DURATION_MAX_HOURS</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">24</span>
# + <span style="color:#ec9ca4">PRECIPITATION_MAX</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">5</span>
# ***
# Mục đích: Thiết lập các ngưỡng giới hạn (Thresholds) dựa trên kiến thức nghiệp vụ để làm sạch dữ liệu:
#
# Nhiệt độ (TEMP): Giới hạn từ -20°F đến 120°F. Các giá trị nằm ngoài khoảng này được coi là lỗi cảm biến hoặc nhiễu, sẽ được chặn (capping) về ngưỡng gần nhất.
#
# Tầm nhìn (VISIBILITY): Giới hạn tối đa 10 dặm. Số liệu lớn hơn thường không mang ý nghĩa thực tế trong báo cáo giao thông.
#
# Thời gian (DURATION): Giới hạn 24 giờ. Các vụ tai nạn ghi nhận kéo dài hơn 1 ngày thường là lỗi nhập liệu (quên đóng hồ sơ), cần được loại bỏ hoặc xử lý.
#
# Lượng mưa (PRECIPITATION): Giới hạn 5 inch. Lượng mưa vượt quá con số này là cực đoan và rất hiếm gặp.

# %%
TOP_N_STATES = 20
TOP_N_CITIES = 100
PARETO_THRESHOLD = 0.8

# %% [markdown]
#     Gán:
# + <span style="color:#ec9ca4">TOP_N_STATES</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">20</span>
# + <span style="color:#ec9ca4">TOP_N_CITIES</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">100</span>
# + <span style="color:#ec9ca4">PARETO_THRESHOLD</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">0.8</span>
#
# Mục đích: TOP_N_STATES,TOP_N_CITIES =(20,100) có nghĩa chỉ lấy top 20 bang, top 100 thành phố có số lượng tai nạn cao nhất. PARETO_THRESHOLD = 0.8 có nghĩa là chỉ lấy những bang, thành phố đóng góp 80% số vụ tai nạn của nước Mỹ.
#
# Tác dụng: giúp ta tập trung xử lý những bang trọng điểm, thành phố nóng nhất, nơi chiếm 80% tổng số vụ tai nạn giao thông.

# %% [markdown]
# ***
# ***
# **EDA**

# %%
import pandas as pd

# %% [markdown]
# Tác dụng: sử dụng thư viện Pandas để xử lý dữ liệu dạng bảng.

# %%
class EDA:
    def __init__(self, df):
        self.df = df.copy()

    def analyze_temporal(self):
        """Analyze temporal patterns"""
        print("\nTemporal Analysis")
        print("-" * 60)

        self.df['Hour'] = self.df['Start_Time'].dt.hour
        self.df['Month'] = self.df['Start_Time'].dt.month
        self.df['DayOfWeek'] = self.df['Start_Time'].dt.dayofweek
        
        print("\nAccidents by year:")
        print(self.df['Year'].value_counts().sort_index())
        
        print("\nPeak hours (top 5):")
        print(self.df['Hour'].value_counts().head())
        
    def analyze_geographic(self):
        """Analyze geographic distribution"""
        print("\nGeographic Analysis")
        print("-" * 60)
        
        print("\nTop 10 states:")
        print(self.df['State'].value_counts().head(10))
        
        print("\nTop 10 cities:")
        city_state = self.df.groupby(['State', 'City']).size().reset_index(name='count')
        print(city_state.nlargest(10, 'count'))
        
    def analyze_severity(self):
        """Analyze severity patterns"""
        print("\nSeverity Analysis")
        print("-" * 60)
        
        severity_stats = self.df.groupby('Severity').agg({
            'ID': 'count',
            'Duration_min': 'mean'
        }).rename(columns={'ID': 'count'})
        
        print(severity_stats)
        
    def check_data_quality(self):
        """Check for missing values and anomalies"""
        print("\nData Quality Check")
        print("-" * 60)
        
        print("\nMissing values:")
        missing = self.df.isnull().sum()
        missing = missing[missing > 0].sort_values(ascending=False)
        if len(missing) > 0:
            print(missing.head(10))
        else:
            print("No missing values")
            
        print(f"\nDuplicate IDs: {self.df.duplicated(subset=['ID']).sum()}")
        
        print("\nNumeric ranges:")
        numeric_cols = ['Temperature(F)', 'Visibility(mi)', 'Precipitation(in)']
        for col in numeric_cols:
            if col in self.df.columns:
                print(f"{col}: min={self.df[col].min():.2f}, max={self.df[col].max():.2f}")
                
    def run_all(self):
        """Run all analysis"""
        print("\n" + "="*60)
        print("Exploratory Data Analysis")
        print("="*60)
        if self.df['Start_Time'].dtype != 'datetime64[ns]':
            self.df['Start_Time'] = pd.to_datetime(self.df['Start_Time'], errors='coerce')
        if self.df['End_Time'].dtype != 'datetime64[ns]':
            self.df['End_Time'] = pd.to_datetime(self.df['End_Time'], errors='coerce')
        
        if 'Duration_min' not in self.df.columns:
            self.df['Duration_min'] = (
                self.df['End_Time'] - self.df['Start_Time']
            ).dt.total_seconds() / 60
        
        self.analyze_temporal()
        self.analyze_geographic()
        self.analyze_severity()
        self.check_data_quality()

# %% [markdown]
# <span style="color:#bfa9e4">class</span> <span style="color:#fff99e">EDA</span>:
#
# Lớp Phân tích dữ liệu thăm dò (EDA) cho tập dữ liệu Tai nạn tại Hoa Kỳ.
# Nhiệm vụ: Chứa các phương thức để kiểm tra sức khỏe dữ liệu, phân tích xu hướng và vẽ biểu đồ sơ bộ trước khi làm sạch.

# %% [markdown]
# ><span style="color:#bfa9e4">def</span> <span style="color:#fff99e">__ init __</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span>, <span style="color:#ff9e64">df</span><span style="color:yellow">)</span>:
# >><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">df</span>.<span style="color:#b3cff6">copy</span><span style="color:yellow">()</span>
#
# Mục đích: Khởi tạo đối tượng EDA. Hoạt động: Nhận một DataFrame (df) và tạo một bản sao .copy() để đảm bảo không làm thay đổi dữ liệu gốc trong quá trình phân tích.

# %% [markdown]
# ><span style="color:#bfa9e4">def</span> <span style="color:#fff99e">analyze_temporal</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>:
# >><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Hour'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>.dt.hour
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Month'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>.dt.month
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'DayOfWeek'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>.dt.dayofweek
# <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:purple">[</span><span style="color:#c2e2a8">'Year'</span><span style="color:purple">]</span>.<span style="color:#b3cff6">value_counts</span><span style="color:purple">()</span>.<span style="color:#b3cff6">sort_index</span><span style="color:purple">()</span><span style="color:yellow">)</span>
# <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:purple">[</span><span style="color:#c2e2a8">'Hour'</span><span style="color:purple">]</span>.<span style="color:#b3cff6">value_counts</span><span style="color:purple">()</span>.<span style="color:#b3cff6">head</span><span style="color:purple">()</span><span style="color:yellow">)</span>
#
# Đoạn code trên sẽ phân rã thời gian trong cột 'Start_Time' để dễ phân tích thành cột giờ (0-23), tháng (1-12) và thứ trong tuần (0:T2, 1:T3, 2:T4, 3:T5, 4:T6, 5:T7, 6:CN)
# Mục đích: Phân tích xu hướng thời gian.
#
# Hoạt động: trích xuất thông tin Giờ, Tháng, Thứ từ cột thời gian và in ra thống kê số vụ tai nạn theo Năm và Top 5 khung giờ cao điểm.

# %% [markdown]
# ><span style="color:#bfa9e4">def</span> <span style="color:#b3cff6">analyze_geographic</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>:
# >><span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:purple">[</span><span style="color:#c2e2a8">'State'</span><span style="color:purple">]</span>.<span style="color:#b3cff6">value_counts</span><span style="color:purple">()</span>.<span style="color:#b3cff6">head</span><span style="color:purple">(</span><span style="color:#ff9e64">10</span><span style="color:purple">)</span><span style="color:yellow">)</span>
# <span style="color:#ec9ca4">city_state</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#b3cff6">groupby</span><span style="color:yellow">(</span><span style="color:purple">[</span><span style="color:#c2e2a8">'State'</span>, <span style="color:#c2e2a8">'City'</span><span style="color:purple">]</span><span style="color:yellow">)</span>.<span style="color:#b3cff6">size</span><span style="color:yellow">()</span>.<span style="color:#b3cff6">reset_index</span><span style="color:yellow">(</span><span style="color:#ff9e64">name</span><span style="color:#74e5ff">=</span><span style="color:#c2e2a8">'count'</span><span style="color:yellow">)</span> <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#ec9ca4">city_state</span>.<span style="color:#b3cff6">nlargest</span><span style="color:purple">(</span><span style="color:#ff9e64">10</span>, <span style="color:#c2e2a8">'count'</span><span style="color:purple">)</span><span style="color:yellow">)</span>
#
# **Phân tích Địa lý**
#
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:purple">[</span><span style="color:#c2e2a8">'State'</span><span style="color:purple">]</span>: Lấy cột Bang.
# + .<span style="color:#b3cff6">value_counts</span><span style="color:purple">()</span>: Đếm số lần xuất hiện của từng bang (Ví dụ: CA xuất hiện 1 triệu lần, TX xuất hiện 500k lần...). Nó tự động sắp xếp giảm dần.
# + .<span style="color:#b3cff6">head</span><span style="color:purple">(</span><span style="color:#ff9e64">10</span><span style="color:purple">)</span>: Cắt lấy 10 dòng đầu tiên (10 bang cao nhất).
#
# Chức năng: In ra Top 10 bang có nhiều vụ tai nạn nhất.
#
# + <span style="color:#b3cff6">groupby</span><span style="color:yellow">(</span><span style="color:purple">[</span><span style="color:#c2e2a8">'State'</span>, <span style="color:#c2e2a8">'City'</span><span style="color:purple">]</span><span style="color:yellow">)</span>: phân biệt được (OR, Portland) khác với (ME, Portland)
#
# + <span style="color:#b3cff6">groupby</span><span style="color:yellow">(</span><span style="color:purple">[</span><span style="color:#c2e2a8">'State'</span>, <span style="color:#c2e2a8">'City'</span><span style="color:purple">]</span><span style="color:yellow">)</span>.<span style="color:#b3cff6">size</span><span style="color:yellow">()</span>: gom những dòng có cùng bang và cùng thành phố lại với nhau.
#
# + <span style="color:#b3cff6">reset_index</span><span style="color:yellow">(</span><span style="color:#ff9e64">name</span><span style="color:#74e5ff">=</span><span style="color:#c2e2a8">'count'</span><span style="color:yellow">)</span>: Biến kết quả gom nhóm (đang ở dạng Series khó nhìn) thành một bảng DataFrame chuẩn chỉnh với 3 cột: State, City, và count (số vụ tai nạn).
#
# <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#ec9ca4">city_state</span>.<span style="color:#b3cff6">nlargest</span><span style="color:purple">(</span><span style="color:#ff9e64">10</span>, <span style="color:#c2e2a8">'count'</span><span style="color:purple">)</span><span style="color:yellow">)</span>: Tìm 10 dòng có giá trị lớn nhất trong cột count (số vụ tai nạn).

# %% [markdown]
# ><span style="color:#bfa9e4">def</span> <span style="color:#b3cff6">analyze_severity</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>:
# >><span style="color:#ec9ca4">severity_stats</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#b3cff6">groupby</span><span style="color:yellow">(</span><span style="color:#c2e2a8">'Severity'</span><span style="color:yellow">)</span>.<span style="color:#b3cff6">agg</span><span style="color:yellow">(</span><span style="color:purple">{</span> <span style="color:#c2e2a8">'ID'</span><span style="color:#b3cff6">:</span> <span style="color:#c2e2a8">'count'</span>, <span style="color:#c2e2a8">'Duration_min'</span><span style="color:#b3cff6">:</span> <span style="color:#c2e2a8">'mean'</span> <span style="color:purple">}</span><span style="color:yellow">)</span>.<span style="color:#b3cff6">rename</span><span style="color:yellow">(</span><span style="color:#ff9e64">columns</span><span style="color:74e5ff">=</span><span style="color:purple">{</span><span style="color:#c2e2a8">'ID'</span><span style="color:#b3cff6">:</span> <span style="color:#c2e2a8">'count'</span><span style="color:purple">}</span><span style="color:yellow">)</span>
#
# **Phân tích mức độ nghiêm trọng (Severity Analysis)**
#
# <span style="color:#b3cff6">groupby</span><span style="color:yellow">(</span><span style="color:#c2e2a8">'Severity'</span><span style="color:yellow">)</span>: Chia dữ liệu thành 4 nhóm (Cấp độ 1, 2, 3, 4).
# <span style="color:#b3cff6">agg</span><span style="color:yellow">(</span><span style="color:purple">{</span> <span style="color:#c2e2a8">'ID'</span><span style="color:#b3cff6">:</span> <span style="color:#c2e2a8">'count'</span>, <span style="color:#c2e2a8">'Duration_min'</span><span style="color:#b3cff6">:</span> <span style="color:#c2e2a8">'mean'</span> <span style="color:purple">}</span><span style="color:yellow">)</span>: Thực hiện 2 phép tính đồng thời cho mỗi nhóm:
#
# + 'ID': 'count': Đếm xem có bao nhiêu vụ tai nạn ở cấp độ đó.
#
# + 'Duration_min': 'mean': Tính xem trung bình tai nạn cấp độ đó kéo dài bao nhiêu phút.
#
# <span style="color:#b3cff6">rename</span><span style="color:yellow">(</span><span style="color:#ff9e64">columns</span><span style="color:74e5ff">=</span><span style="color:purple">{</span><span style="color:#c2e2a8">'ID'</span><span style="color:#b3cff6">:</span> <span style="color:#c2e2a8">'count'</span><span style="color:purple">}</span><span style="color:yellow">)</span>: Đổi tên cột ID thành count cho dễ hiểu hơn.

# %% [markdown]
# ><span style="color:#bfa9e4">def</span> <span style="color:#fff99e">check_data_quality</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>: <span style="color:#575f66">
# >></span> <span style="color:#ec9ca4">missing</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#b3cff6">isnull</span><span style="color:yellow">()</span>.<span style="color:#b3cff6">sum</span><span style="color:yellow">()</span>
# <span style="color:#ec9ca4">missing</span> <span style="color:#74e5ff">=</span> <span style="color:#ec9ca4">missing</span><span style="color:yellow">[</span><span style="color:#ec9ca4">missing</span> <span style="color:#74e5ff">></span> <span style="color:#ff9e64">0</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">sort_values</span><span style="color:yellow">(</span><span style="color:#ff9e64">ascending</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">False</span><span style="color:yellow">)</span>
# <span style="color:#bfa9e4">if</span> <span style="color:#b3cff6">len</span><span style="color:yellow">(</span><span style="color:#ec9ca4">missing</span><span style="color:yellow">)</span> <span style="color:#74e5ff">></span> <span style="color:#ff9e64">0</span>:
# >>><span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#ec9ca4">missing</span>.<span style="color:#b3cff6">head</span><span style="color:yellow">(</span><span style="color:#ff9e64">10</span><span style="color:yellow">))</span>
# >
# >><span style="color:#bfa9e4">else</span>:
# >>><span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">"No missing values"</span><span style="color:yellow">)</span>
# >
# >><span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"\nDuplicate IDs: {self.df.duplicated(subset=['ID']).sum()}"</span><span style="color:yellow">)</span>
#
# 1. Kiểm tra Missing Values (Giá trị bị thiếu):
#
# + <span style="color:#b3cff6">isnull</span><span style="color:yellow">()</span>.<span style="color:#b3cff6">sum</span><span style="color:yellow">()</span>: Đếm tổng số ô trống trong từng cột.
# + </span> <span style="color:#ec9ca4">missing</span><span style="color:yellow">[</span><span style="color:#ec9ca4">missing</span> <span style="color:#74e5ff">></span> <span style="color:#ff9e64">0</span><span style="color:yellow">]</span>: Lọc bỏ các cột sạch (không thiếu gì), chỉ giữ lại các cột có vấn đề.
# + <span style="color:#b3cff6">sort_values</span><span style="color:yellow">(</span><span style="color:#ff9e64">ascending</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">False</span><span style="color:yellow">)</span>: Sắp xếp để cột nào thiếu nhiều nhất nổi lên trên đầu (Ưu tiên xử lý).
# + <span style="color:#ec9ca4">missing</span>.<span style="color:#b3cff6">head</span><span style="color:yellow">(</span><span style="color:#ff9e64">10</span><span style="color:yellow">)</span>: Chỉ in ra Top 10 cột thiếu nhiều nhất để báo cáo đỡ bị dài dòng.

# %% [markdown]
# ><span style="color:#ec9ca4">numeric_cols</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">[</span><span style="color:#c2e2a8">'Temperature(F)'</span>, <span style="color:#c2e2a8">'Visibility(mi)'</span>, <span style="color:#c2e2a8">'Precipitation(in)'</span><span style="color:yellow">]</span>
# ><span style="color:#bfa9e4">for</span> <span style="color:#ff9e64">col</span> <span style="color:#bfa9e4">in</span> <span style="color:#ec9ca4">numeric_cols</span>:
# >><span style="color:#bfa9e4">if</span> <span style="color:#ff9e64">col</span> <span style="color:#74e5ff">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.columns:
# <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#bfa9e4">f</span><span style="color:#c2e2a8">"</span><span style="color:purple">{</span><span style="color:#ec9ca4">col</span><span style="color:purple">}</span><span style="color:#c2e2a8">: min=</span><span style="color:purple">{</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:blue">[</span><span style="color:#ec9ca4">col</span><span style="color:blue">]</span>.<span style="color:#b3cff6">min</span></span><span style="color:blue">()</span><span style="color:#bfa9e4">:.2f</span><span style="color:purple">}</span><span style="color:#c2e2a8">, max=</span><span style="color:purple">{</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:blue">[</span><span style="color:#ec9ca4">col</span><span style="color:blue">]</span>.<span style="color:#74e5ff">max</span><span style="color:blue">()</span><span style="color:#bfa9e4">:.2f</span><span style="color:purple">}</span><span style="color:yellow">)</span>
#
# **Tạo một list chứa tên các cột số quan trọng cần kiểm tra (Nhiệt độ, Tầm nhìn, Lượng mưa)**
#
# Vòng lặp và kiểm tra tồn tại
# + <span style="color:#bfa9e4">for</span> <span style="color:#ff9e64">col</span> <span style="color:#bfa9e4">in</span> <span style="color:#ec9ca4">numeric_cols</span>: Duyệt qua từng tên cột.
#
# + <span style="color:#bfa9e4">if</span> <span style="color:#ff9e64">col</span> <span style="color:#74e5ff">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.columns: Kiểm tra an toàn xem cột đó có thực sự tồn tại trong bảng dữ liệu không (tránh lỗi crash chương trình nếu file csv bị thiếu cột).
#
# In kết quả:
# + .<span style="color:#b3cff6">min</span></span><span style="color:blue">()</span> và .<span style="color:#74e5ff">max</span><span style="color:blue">()</span>: Tìm giá trị nhỏ nhất và lớn nhất.
# + <span style="color:#bfa9e4">:.2f</span>: Định dạng số hiển thị gọn gàng với 2 chữ số sau dấu phẩy.

# %% [markdown]
# ><span style="color:#bfa9e4">def</span> <span style="color:#fff99e">run_all</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>:
# >><span style="color:#bfa9e4">if</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>.dtype <span style="color:#74e5ff">!=</span> <span style="color:#c2e2a8">'datetime64[ns]'</span>:
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#eaf4c1">pd</span>.<span style="color:#b3cff6">to_datetime</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>, <span style="color:#ff9e64">errors</span><span style="color:#74e5ff">=</span><span style="color:#c2e2a8">'coerce'</span><span style="color:yellow">)</span>
# >>
# >><span style="color:#bfa9e4">if</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'End_Time'</span><span style="color:yellow">]</span>.<span style="color:#ec9ca4">dtype</span> <span style="color:#74e5ff">!=</span> <span style="color:#c2e2a8">'datetime64[ns]'</span>:
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'End_Time'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#eaf4c1">pd</span>.<span style="color:#b3cff6">to_datetime</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'End_Time'</span><span style="color:yellow">]</span>, <span style="color:#ff9e64">errors</span><span style="color:#74e5ff">=</span><span style="color:#c2e2a8">'coerce'</span><span style="color:yellow">)</span>
# >>
# >><span style="color:#bfa9e4">if</span> <span style="color:#c2e2a8">'Duration_min'</span> <span style="color:#bfa9e4">not in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>:
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Duration_min'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'End_Time'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">-</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span><span style="color:yellow">)</span>.dt.<span style="color:#b3cff6">total_seconds</span><span style="color:yellow">()</span> <span style="color:#74e5ff">/</span> <span style="color:#ff9e64">60</span>

# %% [markdown]
# **Kiểm tra và ép kiểu thời gian**

# %% [markdown]
# ><span style="color:#bfa9e4">if</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>.dtype <span style="color:#74e5ff">!=</span> <span style="color:#c2e2a8">'datetime64[ns]'</span>:
# >><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#eaf4c1">pd</span>.<span style="color:#b3cff6">to_datetime</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>, <span style="color:#ff9e64">errors</span><span style="color:#74e5ff">=</span><span style="color:#c2e2a8">'coerce'</span><span style="color:yellow">)</span>
#
# + <span style="color:#bfa9e4">if</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>.dtype <span style="color:#74e5ff">!=</span> <span style="color:#c2e2a8">'datetime64[ns]'</span>: kiểm tra xem cột Start_Time hiện tại có khác kiểu dữ liệu thời gian chuẩn datetime64[ns] không.
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#eaf4c1">pd</span>.<span style="color:#b3cff6">to_datetime</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>, <span style="color:#ff9e64">errors</span><span style="color:#74e5ff">=</span><span style="color:#c2e2a8">'coerce'</span><span style="color:yellow">)</span>: Nếu có thì đổi thành datetime64[ns].
# + <span style="color:#ff9e64">errors</span><span style="color:#74e5ff">=</span><span style="color:#c2e2a8">'coerce'</span>: dùng để khi gặp dữ liệu lỗi thì nó sẽ không bị crash, vd: 2019-12-3, NaT,...

# %% [markdown]
# >><span style="color:#bfa9e4">if</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'End_Time'</span><span style="color:yellow">]</span>.<span style="color:#ec9ca4">dtype</span> <span style="color:#74e5ff">!=</span> <span style="color:#c2e2a8">'datetime64[ns]'</span>:
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'End_Time'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#eaf4c1">pd</span>.<span style="color:#b3cff6">to_datetime</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'End_Time'</span><span style="color:yellow">]</span>, <span style="color:#ff9e64">errors</span><span style="color:#74e5ff">=</span><span style="color:#c2e2a8">'coerce'</span><span style="color:yellow">)</span>
#
# + <span style="color:#bfa9e4">if</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'End_Time'</span><span style="color:yellow">]</span>.<span style="color:#ec9ca4">dtype</span> <span style="color:#74e5ff">!=</span> <span style="color:#c2e2a8">'datetime64[ns]'</span>: kiểm tra cột End_Time có khác với định dạng chuẩn của thời gian datetime64[ns] không.
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'End_Time'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#eaf4c1">pd</span>.<span style="color:#b3cff6">to_datetime</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'End_Time'</span><span style="color:yellow">]</span>, <span style="color:#ff9e64">errors</span><span style="color:#74e5ff">=</span><span style="color:#c2e2a8">'coerce'</span><span style="color:yellow">)</span>: nếu có thì đổi thành datetime64[ns].

# %% [markdown]
# >><span style="color:#bfa9e4">if</span> <span style="color:#c2e2a8">'Duration_min'</span> <span style="color:#bfa9e4">not in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>:
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Duration_min'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'End_Time'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">-</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span><span style="color:yellow">)</span>.dt.<span style="color:#b3cff6">total_seconds</span><span style="color:yellow">()</span> <span style="color:#74e5ff">/</span> <span style="color:#ff9e64">60</span>
#
# + <span style="color:#bfa9e4">if</span> <span style="color:#c2e2a8">'Duration_min'</span> <span style="color:#bfa9e4">not in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>: kiểm tra xem trong bảng dữ liệu đã có cột Duration_min chưa.
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Duration_min'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'End_Time'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">-</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span><span style="color:yellow">)</span>.<span style="color:#ec9ca4">dt</span>.<span style="color:#b3cff6">total_seconds</span><span style="color:yellow">()</span> <span style="color:#74e5ff">/</span> <span style="color:#ff9e64">60</span>: dòng tính toán.
#
#     1. <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'End_Time'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">-</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span>: (End_Time - Start_Time)->(Lấy thời gian kết thúc trừ đi thời gian bắt đầu).
#     2. <span style="color:#ec9ca4">dt</span>.<span style="color:#b3cff6">total_seconds</span><span style="color:yellow">()</span>: chuyển đổi khoảng thời gian Timedelta đó thành tổng số Giây.

# %% [markdown]
# >><span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">analyze_temporal</span><span style="color:yellow">()</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">analyze_geographic</span><span style="color:yellow">()</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">analyze_severity</span><span style="color:yellow">()</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">check_data_quality</span><span style="color:yellow">()</span>
#
# **Điều phối quy trình phân tích (Analysis Orchestration)**
#
# Mục đích: Tự động hóa việc chạy toàn bộ các phân tích khám phá chỉ bằng một lệnh gọi hàm duy nhất. Thay vì phải nhớ tên và gọi từng hàm lẻ tẻ, hàm này đóng vai trò như một "Tổng chỉ huy".
#
# Hoạt động chi tiết:
# 1. <span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">analyze_temporal</span><span style="color:yellow">()</span>: Gọi hàm phân tích xu hướng thời gian (Giờ cao điểm, Tai nạn theo năm).
# 2. <span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">analyze_geographic</span><span style="color:yellow">()</span>: Gọi hàm phân tích địa lý (Top bang, Top thành phố).
# 3. <span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">analyze_severity</span><span style="color:yellow">()</span>: Gọi hàm phân tích mức độ nghiêm trọng và thời gian tắc nghẽn.
# 4. <span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">check_data_quality</span><span style="color:yellow">()</span>: Gọi hàm kiểm tra sức khỏe dữ liệu lần cuối (Missing values, Outliers).

# %% [markdown]
# ___
# ___
# **CLEANER**

# %%
import pandas as pd
import numpy as np
import config

# %% [markdown]
# + <span style="color:#bfa9e4">import</span> <span style="color:#eaf4c1">pandas</span> <span style="color:#bfa9e4">as</span> <span style="color:#eaf4c1">pd</span>: sử dụng thư viện Pandas để xử lý dữ liệu dạng bảng (DataFrame) và phân tích dữ liệu.
# + <span style="color:#bfa9e4">import</span> <span style="color:#eaf4c1">numpy</span> <span style="color:#bfa9e4">as</span> <span style="color:#eaf4c1">np</span>: sử dụng thư viện NumPy để hỗ trợ tính toán số học hiệu năng cao và xử lý các giá trị đặc biệt (ví dụ: dùng np.nan để đại diện cho dữ liệu bị thiếu/rỗng).
# + <span style="color:#bfa9e4">import</span> <span style="color:#eaf4c1">config</span>: đọc được các tham số cài đặt chung (như đường dẫn, ngưỡng lọc) từ file config.py

# %% [markdown]
# ><span style="color:#bfa9e4">class</span> <span style="color:#fff99e">DataCleaner</span>:
#
# + Mô tả: Lớp chịu trách nhiệm làm sạch dữ liệu và tạo đặc trưng mới (Feature Engineering).
# + Nhiệm vụ: Biến đổi dữ liệu thô (Raw Data) thành dữ liệu chất lượng cao (Cleaned Data) sẵn sàng cho việc mô hình hóa.

# %% [markdown]
# ><span style="color:#bfa9e4">def</span> <span style="color:#fff99e">__ init __</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span>, <span style="color:#ff9e64">df</span><span style="color:yellow">)</span>:
# >><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">df</span>.<span style="color:#b3cff6">copy</span><span style="color:yellow">()</span>
#
# + Mục đích: Khởi tạo đối tượng làm sạch.
# + Hoạt động: Tạo một bản sao độc lập của dữ liệu để xử lý, đảm bảo an toàn cho dữ liệu gốc.

# %% [markdown]
# ><span style="color:#bfa9e4">def</span> <span style="color:#fff99e">handle_missing</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>:
# >><span style="color:#ec9ca4">numeric_cols</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">[</span><span style="color:#c2e2a8">'Temperature(F)'</span>, <span style="color:#c2e2a8">'Visibility(mi)'</span>, <span style="color:#c2e2a8">'Precipitation(in)'</span><span style="color:yellow">]</span>
# <span style="color:#bfa9e4">for</span> <span style="color:#ff9e64">col</span> <span style="color:#bfa9e4">in</span> <span style="color:#ec9ca4">numeric_cols</span>:
# >>><span style="color:#bfa9e4">if</span> <span style="color:#ff9e64">col</span> <span style="color:#bfa9e4">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>:
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#ff9e64">col</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">fillna</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#ff9e64">col</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">median</span><span style="color:yellow">()</span>, <span style="color:#ff9e64">inplace</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">True</span><span style="color:yellow">)</span>

# %% [markdown]
# Mục đích: Xác định phạm vi các cột dữ liệu định lượng (số thực) cần được xử lý giá trị thiếu.
#
# + <span style="color:#bfa9e4">def</span> <span style="color:#fff99e">handle_missing</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>: định nghĩa phương thức handle_missing chịu trách nhiệm chính trong việc xử lý các ô dữ liệu bị trống.
# + <span style="color:#ec9ca4">numeric_cols</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">[</span><span style="color:#c2e2a8">'Temperature(F)'</span>, <span style="color:#c2e2a8">'Visibility(mi)'</span>, <span style="color:#c2e2a8">'Precipitation(in)'</span><span style="color:yellow">]</span>: khai báo một danh sách (list) chứa tên 3 cột dữ liệu số quan trọng (Nhiệt độ, Tầm nhìn, Lượng mưa) để khoanh vùng các cột cần điền.

# %% [markdown]
# + <span style="color:#bfa9e4">for</span> <span style="color:#ff9e64">col</span> <span style="color:#bfa9e4">in</span> <span style="color:#ec9ca4">numeric_cols</span>: thiết lập vòng lặp để duyệt lần lượt qua từng tên cột đã được định nghĩa trong danh sách numeric_cols.
#
# + <span style="color:#bfa9e4">if</span> <span style="color:#ff9e64">col</span> <span style="color:#bfa9e4">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>: kiểm tra an toàn xem cột hiện tại có thực sự tồn tại trong DataFrame (self.df) hay không. Bước này giúp tránh lỗi chương trình (crash) nếu file dữ liệu đầu vào vô tình bị thiếu cột so với dự kiến.
#
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#ff9e64">col</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">fillna</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#ff9e64">col</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">median</span><span style="color:yellow">()</span>, <span style="color:#ff9e64">inplace</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">True</span><span style="color:yellow">)</span>: thực hiện lệnh cốt lõi là điền khuyết (Imputation). Các ô trống (NaN) trong cột sẽ được thay thế bằng giá trị Trung vị (Median) của chính cột đó. Tham số inplace=True giúp cập nhật trực tiếp sự thay đổi vào bảng dữ liệu gốc mà không cần tạo ra bảng sao chép mới.

# %% [markdown]
# ><span style="color:#ec9ca4">bool_cols</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">[</span><span style="color:#c2e2a8">'Amenity'</span>, <span style="color:#c2e2a8">'Crossing'</span>, <span style="color:#c2e2a8">'Junction'</span>, <span style="color:#c2e2a8">'Railway'</span>, <span style="color:#c2e2a8">'Station'</span>, <span style="color:#c2e2a8">'Stop'</span>, <span style="color:#c2e2a8">'Traffic_Signal'</span><span style="color:yellow">]</span>
# <span style="color:#bfa9e4">for</span> <span style="color:#ff9e64">col</span> <span style="color:#bfa9e4">in</span> <span style="color:#ec9ca4">bool_cols</span>:
# >><span style="color:#bfa9e4">if</span> <span style="color:#ff9e64">col</span> <span style="color:#bfa9e4">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>:
# >>><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#ff9e64">col</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">fillna</span><span style="color:yellow">(</span><span style="color:#ff9e64">False</span>, <span style="color:#ff9e64">inplace</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">True</span><span style="color:yellow">)</span>
# >>
# >><span style="color:#bfa9e4">if</span> <span style="color:#c2e2a8">'Weather_Condition'</span> <span style="color:#bfa9e4">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>:
# >>><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#ff9e64">col</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">fillna</span><span style="color:yellow">(</span><span style="color:#ff9e64">False</span>, <span style="color:#ff9e64">inplace</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">True</span><span style="color:yellow">)</span>
# >>
# >><span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"Missing values handled"</span><span style="color:yellow">)</span>
# + <span style="color:#ec9ca4">bool_cols</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">[</span><span style="color:#c2e2a8">'Amenity'</span>, <span style="color:#c2e2a8">'Crossing'</span>, <span style="color:#c2e2a8">'Junction'</span>, <span style="color:#c2e2a8">'Railway'</span>, <span style="color:#c2e2a8">'Station'</span>, <span style="color:#c2e2a8">'Stop'</span>, <span style="color:#c2e2a8">'Traffic_Signal'</span><span style="color:yellow">]</span>: Khai báo danh sách tên các cột dữ liệu dạng Boolean (Đúng/Sai) liên quan đến hạ tầng giao thông (như tiện ích, vạch kẻ đường, ngã tư, đường sắt, nhà ga, biển báo dừng, đèn giao thông).
# <span style="color:#bfa9e4">for</span> <span style="color:#ff9e64">col</span> <span style="color:#bfa9e4">in</span> <span style="color:#ec9ca4">bool_cols</span>: Tạo vòng lặp để duyệt lần lượt qua từng tên cột trong danh sách bool_cols vừa tạo ở trên.
#
# + <span style="color:#bfa9e4">if</span> <span style="color:#ff9e64">col</span> <span style="color:#bfa9e4">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>: Kiểm tra an toàn xem cột hiện tại có thực sự tồn tại trong bảng dữ liệu (self.df) hay không (tránh lỗi nếu file csv thiếu cột).
#
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#ff9e64">col</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">fillna</span><span style="color:yellow">(</span><span style="color:#ff9e64">False</span>, <span style="color:#ff9e64">inplace</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">True</span><span style="color:yellow">)</span>: Điền các giá trị bị thiếu (NaN) bằng False. Lý do: Giả định rằng nếu dữ liệu không ghi nhận sự hiện diện của hạ tầng (ví dụ không ghi có đèn đỏ), thì mặc định là không có (False).
#
# + <span style="color:#bfa9e4">if</span> <span style="color:#c2e2a8">'Weather_Condition'</span> <span style="color:#bfa9e4">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>: Kiểm tra xem cột 'Điều kiện thời tiết' có tồn tại trong bảng dữ liệu hay không.
#
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Weather_Condition'</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">fillna</span><span style="color:yellow">(</span><span style="color:#c2e2a8">'Clear'</span>, <span style="color:#ff9e64">inplace</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">True</span><span style="color:yellow">)</span>: Điền các ô thiếu thông tin thời tiết bằng giá trị 'Clear' (Trời quang). Lý do: Đây là trạng thái thời tiết phổ biến nhất, dùng làm giá trị mặc định an toàn thay vì xóa bỏ dòng dữ liệu.
#
# + <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"Missing values handled"</span><span style="color:yellow">)</span>: In thông báo ra màn hình để xác nhận quy trình xử lý giá trị thiếu đã hoàn tất thành công.

# %% [markdown]
# ><span style="color:#bfa9e4">def</span> <span style="color:#fff99e">handle_outliers</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>:
# >><span style="color:#bfa9e4">if</span> <span style="color:#c2e2a8">'Temperature(F)'</span> <span style="color:#bfa9e4">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>:
# >>><span style="color:#ec9ca4">outliers</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">((</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Temperature(F)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff"><</span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">TEMP_MIN</span><span style="color:yellow">)</span> <span style="color:#74e5ff">|</span> <span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Temperature(F)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">></span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">TEMP_MAX</span><span style="color:yellow">))</span>.<span style="color:#b3cff6">sum</span><span style="color:yellow">()</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#b3cff6">loc</span><span style="color:yellow">[</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Temperature(F)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff"><</span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">TEMP_MIN</span>, <span style="color:#c2e2a8">'Temperature(F)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">TEMP_MIN</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#b3cff6">loc</span><span style="color:yellow">[</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Temperature(F)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">></span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">TEMP_MAX</span>, <span style="color:#c2e2a8">'Temperature(F)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">TEMP_MAX</span>
# <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"Temperature outliers capped: {outliers}"</span><span style="color:yellow">)</span>
# >>
# >><span style="color:#bfa9e4">if</span> <span style="color:#c2e2a8">'Visibility(mi)'</span> <span style="color:#bfa9e4">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>:
# >>><span style="color:#ec9ca4">outliers</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Visibility(mi)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">></span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">VISIBILITY_MAX</span><span style="color:yellow">)</span>.<span style="color:#b3cff6">sum</span><span style="color:yellow">()</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#b3cff6">loc</span><span style="color:yellow">[</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Visibility(mi)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">></span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">VISIBILITY_MAX</span>, <span style="color:#c2e2a8">'Visibility(mi)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">VISIBILITY_MAX</span>
# <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"Visibility outliers capped: {outliers}"</span><span style="color:yellow">)</span>
# >>
# >><span style="color:#bfa9e4">if</span> <span style="color:#c2e2a8">'Duration_min'</span> <span style="color:#bfa9e4">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>:
# >>><span style="color:#ec9ca4">max_duration</span> <span style="color:#74e5ff">=</span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">DURATION_MAX_HOURS</span> <span style="color:#74e5ff">*</span> <span style="color:#ff9e64">60</span>:
# <span style="color:#ec9ca4">outliers</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Duration_min'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">></span> <span style="color:#ec9ca4">max_duration</span><span style="color:yellow">)</span>.<span style="color:#b3cff6">sum</span><span style="color:yellow">()</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#b3cff6">loc</span><span style="color:yellow">[</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Duration_min'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">></span> <span style="color:#ec9ca4">max_duration</span>, <span style="color:#c2e2a8">'Duration_min'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ec9ca4">max_duration</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#b3cff6">loc</span><span style="color:yellow">[</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Duration_min'</span><span style="color:yellow">]</span> <span style="color:#74e5ff"><</span> <span style="color:#ff9e64">0</span>, <span style="color:#c2e2a8">'Duration_min'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">0</span>:
# <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"Duration outliers capped: {outliers}"</span><span style="color:yellow">)</span>
#
# <span style="color:#bfa9e4">def</span> <span style="color:#fff99e">handle_outliers</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>: Định nghĩa phương thức xử lý các giá trị bất thường (outliers) bằng kỹ thuật Capping (Chặn ngưỡng).
#
# **KHỐI 1: XỬ LÝ NHIỆT ĐỘ (TEMPERATURE)**
#
# + <span style="color:#bfa9e4">if</span> <span style="color:#c2e2a8">'Temperature(F)'</span> <span style="color:#bfa9e4">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>: Kiểm tra xem cột Nhiệt độ có tồn tại trong dữ liệu không.
# + <span style="color:#ec9ca4">outliers</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">((</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Temperature(F)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff"><</span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">TEMP_MIN</span><span style="color:yellow">)</span> <span style="color:#74e5ff">|</span> <span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Temperature(F)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">></span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">TEMP_MAX</span><span style="color:yellow">))</span>.<span style="color:#b3cff6">sum</span><span style="color:yellow">()</span>: Đếm tổng số lượng dòng dữ liệu vi phạm ngưỡng an toàn (nhỏ hơn Min hoặc lớn hơn Max) để báo cáo.
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#b3cff6">loc</span><span style="color:yellow">[</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Temperature(F)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff"><</span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">TEMP_MIN</span>, <span style="color:#c2e2a8">'Temperature(F)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">TEMP_MIN</span>: Thực hiện chặn dưới. Tất cả các giá trị nhiệt độ thấp hơn ngưỡng tối thiểu (ví dụ -20°F) sẽ được gán lại bằng chính giá trị -20°F.
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#b3cff6">loc</span><span style="color:yellow">[</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Temperature(F)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">></span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">TEMP_MAX</span>, <span style="color:#c2e2a8">'Temperature(F)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">TEMP_MAX</span>: Thực hiện chặn trên. Tất cả các giá trị cao hơn ngưỡng tối đa (ví dụ 120°F) sẽ được gán lại bằng 120°F.
# + <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"Temperature outliers capped: {outliers}"</span><span style="color:yellow">)</span>: In ra số lượng bản ghi ngoại lai đã được xử lý.
#
# **KHỐI 2: XỬ LÝ TẦM NHÌN (VISIBILITY)**
#
# + <span style="color:#bfa9e4">if</span> <span style="color:#c2e2a8">'Visibility(mi)'</span> <span style="color:#bfa9e4">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>: Kiểm tra sự tồn tại của cột Tầm nhìn.
# + <span style="color:#ec9ca4">outliers</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Visibility(mi)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">></span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">VISIBILITY_MAX</span><span style="color:yellow">)</span>.<span style="color:#b3cff6">sum</span><span style="color:yellow">()</span>: Đếm số lượng giá trị tầm nhìn vượt quá ngưỡng cho phép (thường là 10 dặm).
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#b3cff6">loc</span><span style="color:yellow">[</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Visibility(mi)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">></span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">VISIBILITY_MAX</span>, <span style="color:#c2e2a8">'Visibility(mi)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">VISIBILITY_MAX</span>: Gán tất cả các giá trị tầm nhìn > 10 dặm về 10 dặm (vì trong báo cáo giao thông, tầm nhìn xa hơn 10 dặm không có nhiều ý nghĩa khác biệt).
# + <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"Visibility outliers capped: {outliers}"</span><span style="color:yellow">)</span>: In kết quả xử lý.
#
# **KHỐI 3: XỬ LÝ THỜI GIAN KÉO DÀI (DURATION)**
#
# + <span style="color:#bfa9e4">if</span> <span style="color:#c2e2a8">'Duration_min'</span> <span style="color:#bfa9e4">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>: Kiểm tra cột Thời lượng tai nạn (đơn vị phút).
# + <span style="color:#ec9ca4">max_duration</span> <span style="color:#74e5ff">=</span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">DURATION_MAX_HOURS</span> <span style="color:#74e5ff">*</span> <span style="color:#ff9e64">60</span>: Chuyển đổi ngưỡng tối đa từ Giờ (trong config) sang Phút để cùng đơn vị với dữ liệu.
# + <span style="color:#ec9ca4">outliers</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Duration_min'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">></span> <span style="color:#ec9ca4">max_duration</span><span style="color:yellow">)</span>.<span style="color:#b3cff6">sum</span><span style="color:yellow">()</span>: Đếm các vụ tai nạn có thời gian kéo dài bất thường (quá lâu).
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#b3cff6">loc</span><span style="color:yellow">[</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Duration_min'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">></span> <span style="color:#ec9ca4">max_duration</span>, <span style="color:#c2e2a8">'Duration_min'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ec9ca4">max_duration</span>: Chặn trên thời gian. Nếu tai nạn kéo dài hơn 24 tiếng (giả sử), ta gán về 24 tiếng để tránh làm lệch giá trị trung bình.
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#b3cff6">loc</span><span style="color:yellow">[</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Duration_min'</span><span style="color:yellow">]</span> <span style="color:#74e5ff"><</span> <span style="color:#ff9e64">0</span>, <span style="color:#c2e2a8">'Duration_min'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">0</span>: Chặn dưới thời gian. Xử lý lỗi logic (thời gian kết thúc nhỏ hơn thời gian bắt đầu) bằng cách gán về 0.
# + <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"Duration outliers capped: {outliers}"</span><span style="color:yellow">)</span>: In kết quả xử lý.

# %% [markdown]
# ><span style="color:#ec9ca4">invalid</span> <span style="color:#74e5ff">=</span> <span style="color:#74e5ff">~</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Severity'</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">isin</span><span style="color:yellow">([</span><span style="color:#ff9e64">1</span>, <span style="color:#ff9e64">2</span>, <span style="color:#ff9e64">3</span>, <span style="color:#ff9e64">4</span><span style="color:yellow">])</span>
# <span style="color:#ec9ca4">removed</span> <span style="color:#74e5ff">=</span> <span style="color:#ec9ca4">invalid</span>.<span style="color:#b3cff6">sum</span><span style="color:yellow">()</span>
# <span style="color:#bfa9e4">if</span> <span style="color:#ec9ca4">removed</span> <span style="color:#74e5ff">></span> <span style="color:#ff9e64">0</span>
# >><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#74e5ff">~</span><span style="color:#ec9ca4">invalid</span><span style="color:yellow">]</span>
# <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"Invalid severity records removed: {removed}"</span><span style="color:yellow">)</span>
#
# <span style="color:#ec9ca4">invalid</span> <span style="color:#74e5ff">=</span> <span style="color:#74e5ff">~</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Severity'</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">isin</span><span style="color:yellow">([</span><span style="color:#ff9e64">1</span>, <span style="color:#ff9e64">2</span>, <span style="color:#ff9e64">3</span>, <span style="color:#ff9e64">4</span><span style="color:yellow">])</span>: Tạo một mặt nạ lọc (boolean mask) để tìm các dòng dữ liệu bị lỗi. Hàm isin([1, 2, 3, 4]) kiểm tra xem mức độ nghiêm trọng có nằm trong chuẩn (từ 1 đến 4) hay không. Dấu ngã ~ (NOT) sẽ đảo ngược kết quả, nghĩa là chọn ra những dòng KHÔNG nằm trong danh sách [1, 2, 3, 4].
#
# <span style="color:#ec9ca4">removed</span> <span style="color:#74e5ff">=</span> <span style="color:#ec9ca4">invalid</span>.<span style="color:#b3cff6">sum</span><span style="color:yellow">()</span>: Đếm tổng số lượng bản ghi không hợp lệ tìm được ở bước trên.
#
# <span style="color:#bfa9e4">if</span> <span style="color:#ec9ca4">removed</span> <span style="color:#74e5ff">></span> <span style="color:#ff9e64">0</span>: Kiểm tra xem có bản ghi lỗi nào không. Nếu biến removed lớn hơn 0, tức là có dữ liệu rác cần phải xóa.
#
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#74e5ff">~</span><span style="color:#ec9ca4">invalid</span><span style="color:yellow">]</span>: Thực hiện lọc bỏ dữ liệu rác. Câu lệnh này giữ lại các dòng mà biến invalid là False (tức là giữ lại các dòng hợp lệ) và gán ngược lại vào self.df.
#
# <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"Invalid severity records removed: {removed}"</span><span style="color:yellow">)</span>: In thông báo ra màn hình số lượng bản ghi đã bị xóa bỏ để người dùng nắm được mức độ sạch của dữ liệu.

# %% [markdown]
# ><span style="color:#bfa9e4">def</span> <span style="color:#fff99e">create_time_features</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>:
# >><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Year'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>.<span style="color:#ec9ca4">dt</span>.<span style="color:#ec9ca4">year</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Month'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>.<span style="color:#ec9ca4">dt</span>.<span style="color:#ec9ca4">month</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Day'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>.<span style="color:#ec9ca4">dt</span>.<span style="color:#ec9ca4">day</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Hour'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>.<span style="color:#ec9ca4">dt</span>.<span style="color:#ec9ca4">hour</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'DayOfWeek'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>.<span style="color:#ec9ca4">dt</span>.<span style="color:#ec9ca4">dayofweek</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'DayName'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>.<span style="color:#ec9ca4">dt</span>.<span style="color:#b3cff6">day_name</span><span style="color:yellow">()</span>

# %% [markdown]
# <span style="color:#bfa9e4">def</span> <span style="color:#fff99e">create_time_features</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>: Định nghĩa phương thức dùng để "bóc tách" cột thời gian gốc (Start_Time) thành các thành phần nhỏ hơn phục vụ cho việc phân tích chuyên sâu.
#
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Year'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>.<span style="color:#ec9ca4">dt</span>.<span style="color:#ec9ca4">year</span>: Trích xuất Năm (ví dụ: 2021). Dùng để phân tích xu hướng tăng/giảm tai nạn theo từng năm hoặc lọc dữ liệu theo năm (filter_by_year).
#
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Month'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>.<span style="color:#ec9ca4">dt</span>.<span style="color:#ec9ca4">month</span>: Trích xuất Tháng (1-12). Dùng để phân tích tính mùa vụ (Seasonality), ví dụ xem tai nạn có tăng cao vào mùa đông (tháng 12) hay không.
#
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Day'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>.<span style="color:#ec9ca4">dt</span>.<span style="color:#ec9ca4">day</span>: Trích xuất Ngày trong tháng (1-31). Dùng để chi tiết hóa dữ liệu xuống cấp độ ngày.
#
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Hour'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>.<span style="color:#ec9ca4">dt</span>.<span style="color:#ec9ca4">hour</span>: Trích xuất Giờ (0-23). Thành phần quan trọng nhất để xác định các khung giờ cao điểm (Rush Hour) sáng và chiều.
#
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'DayOfWeek'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>.<span style="color:#ec9ca4">dt</span>.<span style="color:#ec9ca4">dayofweek</span>: Trích xuất Thứ tự của thứ trong tuần dạng số (0 = Thứ Hai, 6 = Chủ Nhật). Dùng để tính toán logic (ví dụ: if DayOfWeek >= 5 thì là cuối tuần).
#
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'DayName'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span>.<span style="color:#ec9ca4">dt</span>.<span style="color:#b3cff6">day_name</span><span style="color:yellow">()</span>: Trích xuất Tên thứ (Monday, Tuesday...). Dùng để hiển thị trực quan trên biểu đồ hoặc Dashboard (Tableau/PowerBI) thay vì hiển thị các con số 0, 1, 2 khó hiểu.

# %% [markdown]
# ><span style="color:#bfa9e4">if</span> <span style="color:#c2e2a8">'Duration_min'</span> <span style="color:#bfa9e4">not in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>:
# >><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Duration_min'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'End_Time'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">-</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span><span style="color:yellow">)</span>.<span style="color:#ec9ca4">dt</span>.<span style="color:#b3cff6">total_seconds</span><span style="color:yellow">()</span> <span style="color:#74e5ff">/</span> <span style="color:#ff9e64">60</span>
# >
# ><span style="color:#bfa9e4">def</span> <span style="color:#b3cff6">get_time_period</span><span style="color:yellow">(</span><span style="color:#ff9e64">hour</span><span style="color:yellow">)</span>:
# >><span style="color:#bfa9e4">if</span> <span style="color:#ff9e64">6</span> <span style="color:#74e5ff"><=</span> <span style="color:#ff9e64">hour</span> <span style="color:#74e5ff"><</span> <span style="color:#ff9e64">9</span>:
# >>><span style="color:#bfa9e4">return</span> <span style="color:#c2e2a8">'Morning_Rush'</span>
# >>
# >><span style="color:#bfa9e4">elif</span> <span style="color:#ff9e64">9</span> <span style="color:#74e5ff"><=</span> <span style="color:#ff9e64">hour</span> <span style="color:#74e5ff"><</span> <span style="color:#ff9e64">17</span>:
# >>><span style="color:#bfa9e4">return</span> <span style="color:#c2e2a8">'Day'</span>
# >>
# >><span style="color:#bfa9e4">elif</span> <span style="color:#ff9e64">17</span> <span style="color:#74e5ff"><=</span> <span style="color:#ff9e64">hour</span> <span style="color:#74e5ff"><</span> <span style="color:#ff9e64">20</span>:
# >>><span style="color:#bfa9e4">return</span> <span style="color:#c2e2a8">'Evening_Rush'</span>
# >>
# >><span style="color:#bfa9e4">else</span>:
# >>><span style="color:#bfa9e4">return</span> <span style="color:#c2e2a8">'Night'</span>
# >
# ><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Time_Period'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Hour'</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">apply</span><span style="color:yellow">(</span><span style="color:#b3cff6">get_time_period</span><span style="color:yellow">)</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Is_Weekend'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'DayOfWeek'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">>=</span> <span style="color:#ff9e64">5</span><span style="color:yellow">)</span>.<span style="color:#b3cff6">astype</span><span style="color:yellow">(</span><span style="color:#b3cff6">int</span><span style="color:yellow">)</span>
# <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"Time features created: 9 columns"</span><span style="color:yellow">)</span>

# %% [markdown]
# + <span style="color:#bfa9e4">if</span> <span style="color:#c2e2a8">'Duration_min'</span> <span style="color:#bfa9e4">not in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>: Kiểm tra xem cột 'Duration_min' (Thời lượng tai nạn) đã tồn tại hay chưa. Nếu chưa có thì mới thực hiện tính toán để tránh lãng phí tài nguyên máy tính.
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Duration_min'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'End_Time'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">-</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Start_Time'</span><span style="color:yellow">]</span><span style="color:yellow">)</span>.<span style="color:#ec9ca4">dt</span>.<span style="color:#b3cff6">total_seconds</span><span style="color:yellow">()</span> <span style="color:#74e5ff">/</span> <span style="color:#ff9e64">60</span>: Tính toán độ dài vụ tai nạn theo đơn vị phút. Công thức: (Thời gian kết thúc - Thời gian bắt đầu) quy đổi ra tổng số giây, sau đó chia cho 60.
# + <span style="color:#bfa9e4">def</span> <span style="color:#b3cff6">get_time_period</span><span style="color:yellow">(</span><span style="color:#ff9e64">hour</span><span style="color:yellow">)</span>: Định nghĩa một hàm phụ trợ (helper function) để phân loại khung giờ. Hàm này nhận vào một giờ cụ thể (0-23) và trả về nhãn (label) tương ứng như 'Sáng', 'Chiều', 'Cao điểm', 'Đêm'.
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Time_Period'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Hour'</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">apply</span><span style="color:yellow">(</span><span style="color:#b3cff6">get_time_period</span><span style="color:yellow">)</span>: Áp dụng hàm get_time_period vừa định nghĩa ở trên cho toàn bộ cột 'Hour'. Kết quả tạo ra một cột mới phân nhóm thời gian hành vi giao thông (ví dụ: Morning_Rush, Night...).
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Is_Weekend'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'DayOfWeek'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">>=</span> <span style="color:#ff9e64">5</span><span style="color:yellow">)</span>.<span style="color:#b3cff6">astype</span><span style="color:yellow">(</span><span style="color:#b3cff6">int</span><span style="color:yellow">)</span>: Tạo đặc trưng nhị phân (0 hoặc 1) để xác định ngày cuối tuần. Nếu DayOfWeek lớn hơn hoặc bằng 5 (tức là Thứ 7 hoặc Chủ Nhật), giá trị sẽ là 1 (True), ngược lại là 0 (False).
# + <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"Time features created: 9 columns"</span><span style="color:yellow">)</span>: In thông báo xác nhận đã hoàn tất việc tạo ra các cột đặc trưng thời gian mới.

# %% [markdown]
# ><span style="color:#bfa9e4">def</span> <span style="color:#fff99e">create_weather_features</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>:
# >><span style="color:#bfa9e4">if</span> <span style="color:#c2e2a8">'Weather_Condition'</span> <span style="color:#bfa9e4">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>:
# >>><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Is_Rain'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Weather_Condition'</span><span style="color:yellow">]</span>.<span style="color:#ec9ca4">str</span>.<span style="color:#b3cff6">contains</span><span style="color:yellow">(</span> <span style="color:#c2e2a8">'Rain|Drizzle'</span>, <span style="color:#ff9e64">case</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">False</span>, <span style="color:#ff9e64">na</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">False</span> <span style="color:yellow">)</span>.<span style="color:#b3cff6">astype</span><span style="color:yellow">(</span><span style="color:#b3cff6">int</span><span style="color:yellow">)</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Is_Snow'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Weather_Condition'</span><span style="color:yellow">]</span>.<span style="color:#ec9ca4">str</span>.<span style="color:#b3cff6">contains</span><span style="color:yellow">(</span> <span style="color:#c2e2a8">'Snow|Ice'</span>, <span style="color:#ff9e64">case</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">False</span>, <span style="color:#ff9e64">na</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">False</span> <span style="color:yellow">)</span>.<span style="color:#b3cff6">astype</span><span style="color:yellow">(</span><span style="color:#b3cff6">int</span><span style="color:yellow">)</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Is_Fog'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Weather_Condition'</span><span style="color:yellow">]</span>.<span style="color:#ec9ca4">str</span>.<span style="color:#b3cff6">contains</span><span style="color:yellow">(</span> <span style="color:#c2e2a8">'Fog|Mist'</span>, <span style="color:#ff9e64">case</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">False</span>, <span style="color:#ff9e64">na</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">False</span> <span style="color:yellow">)</span>.<span style="color:#b3cff6">astype</span><span style="color:yellow">(</span><span style="color:#b3cff6">int</span><span style="color:yellow">)</span>
# >>
# >><span style="color:#bfa9e4">if</span> <span style="color:#c2e2a8">'Visibility(mi)'</span> <span style="color:#bfa9e4">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>:
# >>><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Low_Visibility'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Visibility(mi)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff"><</span> <span style="color:#ff9e64">1</span><span style="color:yellow">)</span>.<span style="color:#b3cff6">astype</span><span style="color:yellow">(</span><span style="color:#b3cff6">int</span><span style="color:yellow">)</span>
# <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"Weather features created: 4 columns"</span><span style="color:yellow">)</span>

# %% [markdown]
# + <span style="color:#bfa9e4">def</span> <span style="color:#fff99e">create_weather_features</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>: Định nghĩa phương thức để trích xuất các đặc trưng thời tiết từ dạng chuỗi văn bản phức tạp sang dạng số nhị phân (0 và 1) để máy tính dễ xử lý.
#
# + <span style="color:#bfa9e4">if</span> <span style="color:#c2e2a8">'Weather_Condition'</span> <span style="color:#bfa9e4">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>: Kiểm tra xem cột 'Điều kiện thời tiết' có tồn tại trong dữ liệu không trước khi xử lý.
#
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Is_Rain'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> ...: Tạo cột mới 'Is_Rain' (Có mưa không). Sử dụng hàm str.contains('Rain|Drizzle') để tìm kiếm từ khóa 'Mưa' hoặc 'Mưa phùn' trong chuỗi mô tả.
#
#     1. case=False: Không phân biệt chữ hoa thường.
#
#     2. na=False: Nếu dữ liệu bị trống (NaN), coi như là không mưa (False).
#
#     3. astype(int): Chuyển đổi True/False thành 1/0.
#
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Is_Snow'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> ...: Tương tự như trên, tạo cột 'Is_Snow' (Có tuyết không) bằng cách tìm từ khóa 'Snow' (Tuyết) hoặc 'Ice' (Băng). Đây là điều kiện lái xe rất nguy hiểm.
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Is_Fog'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> ...: Tạo cột 'Is_Fog' (Có sương mù không) bằng cách tìm từ khóa 'Fog' hoặc 'Mist'.
# + <span style="color:#bfa9e4">if</span> <span style="color:#c2e2a8">'Visibility(mi)'</span> <span style="color:#bfa9e4">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>: Kiểm tra sự tồn tại của cột Tầm nhìn.
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Low_Visibility'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Visibility(mi)'</span><span style="color:yellow">]</span> <span style="color:#74e5ff"><</span> <span style="color:#ff9e64">1</span><span style="color:yellow">)</span>.<span style="color:#b3cff6">astype</span><span style="color:yellow">(</span><span style="color:#b3cff6">int</span><span style="color:yellow">)</span>: Tạo cột cảnh báo 'Tầm nhìn thấp'. Nếu tầm nhìn dưới 1 dặm, gán giá trị 1 (Nguy hiểm), ngược lại là 0 (An toàn).
# + <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"Weather features created: 4 columns"</span><span style="color:yellow">)</span>: In thông báo xác nhận đã tạo thành công 4 cột đặc trưng thời tiết mới.

# %% [markdown]
# ><span style="color:#bfa9e4">def</span> <span style="color:#fff99e">create_infrastructure_features</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>:
# >><span style="color:#ec9ca4">infra_cols</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">[</span><span style="color:#c2e2a8">'Amenity'</span>, <span style="color:#c2e2a8">'Crossing'</span>, <span style="color:#c2e2a8">'Junction'</span>, <span style="color:#c2e2a8">'Railway'</span>, <span style="color:#c2e2a8">'Station'</span>, <span style="color:#c2e2a8">'Stop'</span>, <span style="color:#c2e2a8">'Traffic_Signal'</span><span style="color:yellow">]</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Infra_Score'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">0</span>
# <span style="color:#bfa9e4">for</span> <span style="color:#ff9e64">col</span> <span style="color:#bfa9e4">in</span> <span style="color:#ec9ca4">infra_cols</span>:
# >>><span style="color:#bfa9e4">if</span> <span style="color:#ff9e64">col</span> <span style="color:#bfa9e4">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>:
# >>>><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Infra_Score'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">+=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#ff9e64">col</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">astype</span><span style="color:yellow">(</span><span style="color:#b3cff6">int</span><span style="color:yellow">)</span>
# >>>><span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"Infrastructure features created: 1 column"</span><span style="color:yellow">)</span>

# %% [markdown]
# + <span style="color:#bfa9e4">def</span> <span style="color:#fff99e">create_infrastructure_features</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>: Định nghĩa phương thức để tổng hợp thông tin hạ tầng giao thông thành một chỉ số duy nhất, giúp đơn giản hóa dữ liệu cho mô hình.
# + <span style="color:#ec9ca4">infra_cols</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">[</span>...<span style="color:yellow">]</span>: Khai báo danh sách các cột đại diện cho các yếu tố hạ tầng (Tiện ích, Vạch kẻ đường, Giao lộ, Đường sắt, Nhà ga, Biển báo dừng, Đèn tín hiệu).
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Infra_Score'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:#ff9e64">0</span>: Khởi tạo cột mới tên là 'Infra_Score' (Điểm hạ tầng) với giá trị ban đầu bằng 0 cho tất cả các dòng.
# + <span style="color:#bfa9e4">for</span> <span style="color:#ff9e64">col</span> <span style="color:#bfa9e4">in</span> <span style="color:#ec9ca4">infra_cols</span>: Bắt đầu vòng lặp duyệt qua từng loại hạ tầng trong danh sách.
# + <span style="color:#bfa9e4">if</span> <span style="color:#ff9e64">col</span> <span style="color:#bfa9e4">in</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#ec9ca4">columns</span>: Kiểm tra an toàn xem cột đó có tồn tại trong dữ liệu không.
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Infra_Score'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">+=</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#ff9e64">col</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">astype</span><span style="color:yellow">(</span><span style="color:#b3cff6">int</span><span style="color:yellow">)</span>: Cộng dồn điểm số.
# + <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"Infrastructure features created: 1 column"</span><span style="color:yellow">)</span>: In thông báo xác nhận đã tạo thành công cột điểm số hạ tầng.
#
#     1. astype(int): Chuyển đổi giá trị Boolean (True/False) thành số nguyên (1/0).
#
#     2. +=: Nếu tại địa điểm tai nạn có đèn giao thông (True -> 1) và có vạch kẻ đường (True -> 1), điểm Infra_Score sẽ tăng lên.
#
# Ý nghĩa: Điểm càng cao nghĩa là khu vực đó càng phức tạp, có nhiều biển báo/hạ tầng giao thông.

# %% [markdown]
# ><span style="color:#bfa9e4">def</span> <span style="color:#fff99e">create_location_id</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>:
# >><span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">"\nCreating location ID"</span><span style="color:yellow">)</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Location_ID'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'State'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">+</span> <span style="color:#c2e2a8">''</span> <span style="color:#74e5ff">+</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'City'</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">fillna</span><span style="color:yellow">(</span><span style="color:#c2e2a8">'Unknown'</span><span style="color:yellow">)</span> <span style="color:#74e5ff">+</span> <span style="color:#c2e2a8">''</span> <span style="color:#74e5ff">+</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Street'</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">fillna</span><span style="color:yellow">(</span><span style="color:#c2e2a8">'Unknown'</span><span style="color:yellow">)</span> <span style="color:yellow">)</span>

# %% [markdown]
# + <span style="color:#bfa9e4">def</span> <span style="color:#fff99e">create_location_id</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>: Định nghĩa phương thức để tạo ra một "khóa đại diện" (Surrogate Key) duy nhất cho mỗi địa điểm xảy ra tai nạn, phục vụ cho việc tạo bảng Dimension Location sau này.
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Location_ID'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">=</span> <span style="color:yellow">(</span>...<span style="color:yellow">)</span>: Tạo một cột mới tên là Location_ID. Giá trị của cột này được tạo bằng cách nối chuỗi (String Concatenation) thông tin từ 3 cột địa lý khác nhau.
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'State'</span><span style="color:yellow">]</span> <span style="color:#74e5ff">+</span> <span style="color:#c2e2a8">'_'</span> <span style="color:#74e5ff">+</span>: Lấy tên Bang (ví dụ: CA) cộng với dấu gạch dưới để làm phần đầu của ID.
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'City'</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">fillna</span><span style="color:yellow">(</span><span style="color:#c2e2a8">'Unknown'</span><span style="color:yellow">)</span> <span style="color:#74e5ff">+</span> <span style="color:#c2e2a8">'_'</span> <span style="color:#74e5ff">+</span>: Lấy tên Thành phố.
#
# Quan trọng: Phải dùng .fillna('Unknown') vì nếu tên thành phố bị trống (NaN), phép cộng chuỗi sẽ bị lỗi hoặc ra kết quả NaN. Ta thay thế ô trống bằng chữ 'Unknown'.
#
# Ví dụ: Nếu thành phố là 'Miami', kết quả tạm thời là FL_Miami_.
#
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">[</span><span style="color:#c2e2a8">'Street'</span><span style="color:yellow">]</span>.<span style="color:#b3cff6">fillna</span><span style="color:yellow">(</span><span style="color:#c2e2a8">'Unknown'</span><span style="color:yellow">)</span>: Lấy tên Đường phố (cũng xử lý ô trống tương tự).
#
# Kết quả cuối cùng: Tạo ra một ID duy nhất kiểu như CA_Los Angeles_Main St. ID này giúp phân biệt rõ ràng các địa điểm, kể cả khi trùng tên đường nhưng khác thành phố.

# %% [markdown]
# ><span style="color:#bfa9e4">def</span> <span style="color:#fff99e">save_cleaned_data</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>:
# >><span style="color:#ec9ca4">output_path</span> <span style="color:#74e5ff">=</span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">CLEANED_DIR</span> <span style="color:#74e5ff">/</span> <span style="color:#c2e2a8">"accidents_cleaned.csv"</span> <span style="color:#ec9ca4">output_path</span>.<span style="color:#ec9ca4">parent</span>.<span style="color:#b3cff6">mkdir</span><span style="color:yellow">(</span><span style="color:#ff9e64">parents</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">True</span>, <span style="color:#ff9e64">exist_ok</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">True</span><span style="color:yellow">)</span>
# <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"\nSaving cleaned data to {output_path}"</span><span style="color:yellow">)</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#b3cff6">to_csv</span><span style="color:yellow">(</span><span style="color:#ec9ca4">output_path</span>, <span style="color:#ff9e64">index</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">False</span><span style="color:yellow">)</span>
# <span style="color:#ec9ca4">file_size</span> <span style="color:#74e5ff">=</span> <span style="color:#ec9ca4">output_path</span>.<span style="color:#b3cff6">stat</span><span style="color:yellow">()</span>.<span style="color:#ec9ca4">st_size</span> <span style="color:#74e5ff">/</span> <span style="color:yellow">(</span><span style="color:#ff9e64">1024</span><span style="color:#74e5ff">**</span><span style="color:#ff9e64">2</span><span style="color:yellow">)</span>
# <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"Saved: {len(self.df):,} records ({file_size:.1f} MB)"</span><span style="color:yellow">)</span>

# %% [markdown]
# + <span style="color:#bfa9e4">def</span> <span style="color:#fff99e">save_cleaned_data</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>: Định nghĩa phương thức để ghi dữ liệu đã được làm sạch và xử lý (Cleaned Data) ra ổ cứng dưới dạng file CSV.
# + <span style="color:#ec9ca4">output_path</span> <span style="color:#74e5ff">=</span> <span style="color:#f8f8f2">config</span>.<span style="color:#ec9ca4">CLEANED_DIR</span> <span style="color:#74e5ff">/</span> <span style="color:#c2e2a8">"accidents_cleaned.csv"</span>: Xác định đường dẫn file đầu ra. Sử dụng biến CLEANED_DIR từ file config.py để đảm bảo file được lưu đúng vào thư mục data/processed/cleaned mà không cần gõ đường dẫn thủ công.
# + <span style="color:#ec9ca4">output_path</span>.<span style="color:#ec9ca4">parent</span>.<span style="color:#b3cff6">mkdir</span><span style="color:yellow">(</span><span style="color:#ff9e64">parents</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">True</span>, <span style="color:#ff9e64">exist_ok</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">True</span><span style="color:yellow">)</span>: Tạo thư mục chứa file nếu nó chưa tồn tại.
#
# parents=True: Cho phép tạo cả các thư mục cha bị thiếu (ví dụ: tạo folder processed trước rồi mới tạo cleaned).
#
# exist_ok=True: Không báo lỗi nếu thư mục đã có sẵn.
#
# + <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"\nSaving cleaned data to {output_path}"</span><span style="color:yellow">)</span>: In thông báo đường dẫn nơi file sẽ được lưu để người dùng theo dõi.
# + <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>.<span style="color:#b3cff6">to_csv</span><span style="color:yellow">(</span><span style="color:#ec9ca4">output_path</span>, <span style="color:#ff9e64">index</span><span style="color:#74e5ff">=</span><span style="color:#ff9e64">False</span><span style="color:yellow">)</span>: Thực hiện ghi DataFrame vào file CSV. Tham số index=False cực kỳ quan trọng để không lưu cột chỉ mục (0, 1, 2...) vào file, giúp file gọn nhẹ hơn.
# + <span style="color:#ec9ca4">file_size</span> <span style="color:#74e5ff">=</span> <span style="color:#ec9ca4">output_path</span>.<span style="color:#b3cff6">stat</span><span style="color:yellow">()</span>.<span style="color:#ec9ca4">st_size</span> <span style="color:#74e5ff">/</span> <span style="color:yellow">(</span><span style="color:#ff9e64">1024</span><span style="color:#74e5ff">**</span><span style="color:#ff9e64">2</span><span style="color:yellow">)</span>: Tính toán dung lượng file vừa lưu. Lấy kích thước byte (st_size) chia cho 1024^2 để chuyển đổi sang đơn vị Megabyte (MB).
# + <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"Saved: {len(self.df):,} records ({file_size:.1f} MB)"</span><span style="color:yellow">)</span>: In báo cáo tổng kết gồm tổng số dòng dữ liệu (records) và dung lượng file (MB) đã lưu thành công.

# %% [markdown]
# ><span style="color:#bfa9e4">def</span> <span style="color:#fff99e">run_all</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>:
# >><span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">"\n"</span> <span style="color:#74e5ff">+</span> <span style="color:#c2e2a8">"="</span><span style="color:#74e5ff"></span><span style="color:#ff9e64">60</span><span style="color:yellow">)</span>
# <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">"Data Cleaning Pipeline"</span><span style="color:yellow">)</span>
# <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">"="</span><span style="color:#74e5ff"></span><span style="color:#ff9e64">60</span><span style="color:yellow">)</span>
# <span style="color:#ec9ca4">initial_count</span> <span style="color:#74e5ff">=</span> <span style="color:#b3cff6">len</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">)</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">handle_missing</span><span style="color:yellow">()</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">handle_outliers</span><span style="color:yellow">()</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">create_time_features</span><span style="color:yellow">()</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">create_weather_features</span><span style="color:yellow">()</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">create_infrastructure_features</span><span style="color:yellow">()</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">create_location_id</span><span style="color:yellow">()</span>
# <span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">save_cleaned_data</span><span style="color:yellow">()</span>
# <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"\nCleaning complete: {initial_count:,} -> {len(self.df):,} records"</span><span style="color:yellow">)</span>
# <span style="color:#bfa9e4">return</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>

# %% [markdown]
# + <span style="color:#bfa9e4">def</span> <span style="color:#fff99e">run_all</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span><span style="color:yellow">)</span>: Định nghĩa phương thức chính (main method) để điều phối toàn bộ đường ống làm sạch dữ liệu (Cleaning Pipeline). Thay vì gọi từng hàm lẻ tẻ, người dùng chỉ cần gọi hàm này một lần duy nhất.
# + <span style="color:#b3cff6">print</span><span style="color:yellow">(</span>...<span style="color:yellow">)</span>: In tiêu đề trang trí ra màn hình console để đánh dấu bắt đầu quá trình xử lý, giúp dễ theo dõi log khi chạy chương trình.
# + <span style="color:#ec9ca4">initial_count</span> <span style="color:#74e5ff">=</span> <span style="color:#b3cff6">len</span><span style="color:yellow">(</span><span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span><span style="color:yellow">)</span>: Ghi lại tổng số lượng dòng dữ liệu ban đầu trước khi xử lý. Biến này dùng để so sánh hiệu quả sau khi lọc bỏ dữ liệu rác.
# + <span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">handle_missing</span><span style="color:yellow">()</span>: Gọi hàm xử lý giá trị thiếu (đã định nghĩa trước đó).
# + <span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">handle_outliers</span><span style="color:yellow">()</span>: Gọi hàm xử lý giá trị ngoại lai (Capping).
# + <span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">create_..._features</span><span style="color:yellow">()</span>: Lần lượt gọi các hàm tạo đặc trưng mới (Thời gian, Thời tiết, Hạ tầng) và tạo mã định danh địa điểm.
# + <span style="color:#ff9e64">self</span>.<span style="color:#b3cff6">save_cleaned_data</span><span style="color:yellow">()</span>: Gọi hàm lưu kết quả cuối cùng ra file CSV.
# + <span style="color:#b3cff6">print</span><span style="color:yellow">(</span><span style="color:#c2e2a8">f"\nCleaning complete: {initial_count:,} -> {len(self.df):,} records"</span><span style="color:yellow">)</span>: In báo cáo tổng kết, so sánh số lượng bản ghi trước và sau khi làm sạch để người dùng biết đã loại bỏ bao nhiêu dòng dữ liệu lỗi.
# + <span style="color:#bfa9e4">return</span> <span style="color:#ff9e64">self</span>.<span style="color:#ec9ca4">df</span>: Trả về DataFrame đã sạch sẽ hoàn chỉnh để có thể sử dụng ngay cho các bước tiếp theo (như tách bảng Star Schema) mà không cần đọc lại từ file.
